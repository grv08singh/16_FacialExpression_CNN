# %%
import os
from pathlib import Path
import gdown

# %%
file_id = "1k8UZbm9cVmCxLx-6mUOapMwa4Dvnbkce"

# %%
output = Path("data.zip")

# %%
url = f"https://drive.google.com/uc?id={file_id}"
gdown.download(url, output, quiet=False, fuzzy=True, use_cookies=False)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1k8UZbm9cVmCxLx-6mUOapMwa4Dvnbkce

# %%
url = "https://drive.google.com/file/d/1nQcgsr3naNzYmp0hF7DvG_2P2hKZ-6m7/view?usp=sharing"
gdown.download(url, output, quiet=False, fuzzy=True)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1nQcgsr3naNzYmp0hF7DvG_2P2hKZ-6m7

# %%
import gdown
import os

# Clear gdown cookies cache
cookies_path = os.path.expanduser("~/.cache/gdown/cookies.txt")
if os.path.exists(cookies_path):
    os.remove(cookies_path)
    print("Cleared cookies cache")

# Now retry
gdown.download(
    "https://drive.google.com/uc?id=1k8UZbm9cVmCxLx-6mUOapMwa4Dvnbkce",
    "output.zip",
    quiet=False,
    fuzzy=True,
    use_cookies=False
)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1k8UZbm9cVmCxLx-6mUOapMwa4Dvnbkce

# %%
import requests

def download_from_gdrive(file_id, dest):
    session = requests.Session()
    URL = "https://drive.google.com/uc?export=download"
    
    response = session.get(URL, params={"id": file_id}, stream=True)
    
    # Handle the virus scan warning page for large files
    token = None
    for key, value in response.cookies.items():
        if key.startswith("download_warning"):
            token = value
            break

    if token:
        response = session.get(URL, params={"id": file_id, "confirm": token}, stream=True)

    with open(dest, "wb") as f:
        for chunk in response.iter_content(chunk_size=32768):
            if chunk:
                f.write(chunk)
    print(f"Saved to {dest}")

download_from_gdrive("1k8UZbm9cVmCxLx-6mUOapMwa4Dvnbkce", "output.zip")
# Out:
# Saved to output.zip
